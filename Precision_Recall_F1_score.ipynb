# %% [raw]
# Let us assume we have a data of dog images and also the other images in the data. Our target to find the dog image correctly finding the accuracy and recall and the F1_score of the data
#
# assumed data
#  dog, no dog, dog, dog, dog, no dog, no dog, dog, dog, no dog

# %%
# To display an image in Python, you can use libraries such as Matplotlib
# data that we are assuming only we are visulizing the data not for the main code 

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
image_path = "assumed_data.png"
img = mpimg.imread(image_path)

# Set the figure size and display the image
plt.figure(figsize=(10, 10))  # Width = 10 inches, Height = 10 inches
plt.imshow(img)
plt.axis('off') 
plt.show()

# %% [raw]
# now let us assume the prediction values according to the data
#
# prediction data
#  dog, dog, dog, no dog, dog, no dog, dog, no dog, dog, dog

# %%
# data that we are assuming only we are visulizing and understanding the problem, this data is not for the main code 

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
image_path = "assumed_prediction_data.png"
img = mpimg.imread(image_path)

# Set the figure size and display the image
plt.figure(figsize=(10, 10))  # Width = 10 inches, Height = 10 inches
plt.imshow(img)
plt.axis('off') 
plt.show()

# %% [raw]
# let us classify the prediction
#
# True Positive (TP): These are the cases where we correctly predict the target class (dog).
# Example: True Positive = 4. Here, we correctly predicted 4 dogs (indexes: 1, 3, 5, 9), which are indeed dogs in reality.
#
# False Positive (FP): These are the cases where we incorrectly predict the target class (dog) for instances that are not actually dogs.
# Example: False Positive = 3. Here, we incorrectly predicted 3 instances as dogs (indexes: 2, 7, 10), but they are not dogs in reality.
#
# True Negative (TN): These are the cases where we correctly predict a negative class (not a dog).
# Example: True Negative = 1. Here, we correctly predicted 1 instance as not a dog (index: 6), and in reality, it is not a dog.
#
# False Negative (FN): These are the cases where we incorrectly predict a negative class (not a dog) for instances that are actually dogs.
# Example: False Negative = 2. Here, we incorrectly predicted 2 instances as not dogs (indexes: 4, 8), but in reality, they are dogs.

# %% [raw]
# let us classify the prediction
#
# For correct prediction we call True Positive
# True Positive = 4 here we predicted 4 dogs correctly (index = 1, 3, 5, 9) in reality
#
# For wrong prediction we call False Positive
# False Positive = 3 here we predicted 3 wrong which are not dogs (index = 2, 7, 10) in reality they are false
#
# Where the prediction of the image correctly where the image is not dog or any other of our target then we call True Negative
# True Negative = 1 here we predicted a image correctly which is not a dog (index = 6) in reality
#
# Where the prediction of the image is wrong where the image is dog not showing as dog or any other targert then we call False Nagative
# False Negative = 2 here we predicted 2 wrong which are dogs we but we predicted as no dog (index = 4, 8)

# %%
# data that we are assuming only we are visulizing and understanding the problem, this data is not for the main code 

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
image_path = "assumed_predict.png"
img = mpimg.imread(image_path)

# Set the figure size and display the image
plt.figure(figsize=(10, 10))  # Width = 10 inches, Height = 10 inches
plt.imshow(img)
plt.axis('off') 
plt.show()

# %% [raw]
# let us check and know about the accuracy
#
# From the above prediction we got 5 correct and valid answers
#
# Accuracy --> 5/10 = 0.5  (no.of correct answers/ total no.of images)

# %% [raw]
# let us check and know about precision
# Now let us look on True positive and False positive where we assumed first (cell no= 4,5,6) of index = 1, 2, 3, 5, 7, 9, 10
#
# True Positive (TP) = 4    False Positive (FP) = 3
#
# precision formula
# TP/[TP + FP]
#
# precision --> 4/7 = 0.57

# %% [raw]
# let us check and know about recall
#
# Now from the data we have 6 dog images we predicted 4 of them as correct as the dog image index = 1, 3, 5, 9
#
# True Positive (TP) = 4     False Negative (FN) = 2
#
# recall formula
# TP/[TP + FN]
#
# recall --> 4/6 = 0.67

# %% [raw]
# let us check about no dog conditions
#
# precision --> 1/3 = 0.33   recall --> 1/4 = 0.25

# %% [raw]
# f1 score formula
#
# Formula:
# 𝐹1 = 2 × Precision × Recall/Precision + Recall

# %%
# Main code
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix , classification_report
import pandas as pd
import seaborn as sns

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,10), fontsize=14):
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('Truth')
    plt.xlabel('Prediction')

# %%
truth =      ["Dog","Not a dog","Dog","Dog","Dog", "Not a dog", "Not a dog","Dog","Dog", "Not a dog"]
prediction = ["Dog","Dog","Dog","Not a dog","Dog", "Not a dog", "Dog", "Not a dog", "Dog", "Dog"]

# %%
cm = confusion_matrix(truth,prediction)
print_confusion_matrix(cm,["Dog","Not a dog"])

# %%
print(classification_report(truth, prediction))
# Out:
#               precision    recall  f1-score   support
#
#          Dog       0.57      0.67      0.62         6
#    Not a dog       0.33      0.25      0.29         4
#
#     accuracy                           0.50        10
#    macro avg       0.45      0.46      0.45        10
# weighted avg       0.48      0.50      0.48        10

# %% [markdown]
# ### f1 score for Dog class

# %%
2*(0.57*0.67/(0.57+0.67))
# Out:
# 0.6159677419354839

# %% [markdown]
# ### f1 score for Not a dog class

# %%
2*(0.33*0.25/(0.33+0.25))
# Out:
# 0.2844827586206896
